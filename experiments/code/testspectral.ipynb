# %%
import numpy as np
import networkx as nx
import random
import copy
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.colors as mcolors
import matplotlib.patches as patches
from matplotlib.colors import LinearSegmentedColormap
from IPython.display import HTML, display
from Graphclass_module import Graphclass

# %%
edges = [(0,1,0),(0,2,0),(1,0,1),(1,2,0),(2,0,1),(2,1,1)]
G = nx.DiGraph()
for u, v, color in edges:
    G.add_edge(u, v, color=color)
weights = np.array([[0,1.56,0.77],[0.94,0,0.54],[0.51,0.32,0]])

# %%
print(G)
# Out:
# DiGraph with 3 nodes and 6 edges

# %%
print(weights)
# Out:
# [[0.   1.56 0.77]
#  [0.94 0.   0.54]
#  [0.51 0.32 0.  ]]

# %%
test = Graphclass(4,8,3)

# %%
test.use_premade(G,weights)

# %%
print(test.num_nodes)
# Out:
# 3

# %%
test.visualize_graph(test.G)

# %%
print(test.weights)
# Out:
# [[0.   1.56 0.77]
#  [0.94 0.   0.54]
#  [0.51 0.32 0.  ]]

# %%
test.subnetworks, test.dirty_subnetworks = test.breadth_first(0)
test.dirty_radii = test.spectral_radius(test.dirty_subnetworks)
test.dirty_predicted = test.predict(test.dirty_radii, test.dirty_subnetworks)
test.radii = test.spectral_radius(test.subnetworks)
test.history, test.converged, test.zero_nodes = test.simulate_linear()
test.predicted = test.predict(test.radii,test.subnetworks)

# %%
test.visualize_behavior()

# %%
test.visualize_subnetworks(test.subnetworks)

# %%
print(test.radii)
# Out:
# [1.566526668965511, 1.566526668965511]

# %%
test.radii = test.spectral_radius(test.subnetworks)
